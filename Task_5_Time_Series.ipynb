# %% [markdown]
# <a href="https://colab.research.google.com/github/sayyedarbaz6/Python-practice-programs/blob/main/Task_5_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'ARG'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'BRA'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'ESP'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'FRA'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'GER'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()

# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/fifa.xls')
df = pd.DataFrame(data, columns = ['Date', 'ITA'])

# Set the Date as Index
df['Date'] = pd.to_datetime(df['Date'])
df.index = df['Date']
del df['Date']


df.plot(figsize=(15, 6))
plt.show()
